# %% [markdown]
# ## add empty sentences to data

# %%
import json

def add_example_field(json_path, output_path=None):
    # 默认输出路径为原路径加上 "_with_example"
    if output_path is None:
        if json_path.endswith(".json"):
            output_path = json_path.replace(".json", "_t.json")
        else:
            output_path = json_path + "_t.json"

    # 读取原始 JSON 文件
    with open(json_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    # 为每个词条添加 "例句" 字段
    for entry in data:
        entry["翻译"] = ""

    # 写入新文件
    with open(output_path, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

    print(f"处理完成，已保存到: {output_path}")

# add_example_field("public/data/adj_base.json")
# add_example_field("public/data/adj_steigerung.json")
# add_example_field("public/data/nomen_obj.json")
# add_example_field("public/data/nomen_people.json")
# add_example_field("public/data/verben_base.json")
# add_example_field("public/data/verben_phrasen.json")
# Out:
# 处理完成，已保存到: public/data/adj_base_t.json
# 处理完成，已保存到: public/data/adj_steigerung_t.json

# %% [markdown]
# ## for adj base

# %%
import json
import os
import re
import random

def build_adj_patterns(word):
    """
    给定一个德语形容词词根，返回所有常见变形的正则（word boundary 保证只匹配单词）。
    如 'gepunktet' → r'\bgepunktet(?:e|es|er|en|em|n|s)?\b'
    """
    # 常见形容词词尾
    endings = ['', 'e', 'es', 'er', 'en', 'em', 'n', 's', 'em', 'er', 'es', 'en']
    patterns = [
        rf"\b{re.escape(word)}{end}\b" for end in endings
    ]
    # 合成为一个大正则
    pattern = re.compile('|'.join(patterns), flags=re.IGNORECASE)
    return pattern

def sentences_adj_base(json_path, opensub_folder):
    # 1. 读取单词本 JSON
    with open(json_path, "r", encoding="utf-8") as f:
        word_list = json.load(f)

    # 2. 构建未被填充例句的词根集合，以及映射（词根 -> json entry 对象引用）
    unfilled = set()
    entry_map = {}
    pattern_map = {}

    for entry in word_list:
        if entry.get("例句", "") == "" and entry.get("单词"):
            word = entry["单词"]
            unfilled.add(word)
            entry_map[word] = entry
            pattern_map[word] = build_adj_patterns(word)

    print(f"初始需要填充例句的单词数: {len(unfilled)}")

    # 3. 遍历 OpenSubtitles 的 txt 文件
    part_files = sorted(
        [f for f in os.listdir(opensub_folder) if f.startswith("part_") and f.endswith(".txt")],
        key=lambda x: int(x.split("_")[1].split(".")[0])
    )
    random.shuffle(part_files)

    for fname in part_files:
        if not unfilled:
            print("所有单词都已找到例句，提前结束！")
            break

        fpath = os.path.join(opensub_folder, fname)
        with open(fpath, "r", encoding="utf-8", errors="ignore") as fin:
            for line in fin:
                sent = line.strip()
                if not sent:
                    continue
                for word in list(unfilled):
                    # 使用正则支持变体匹配
                    if pattern_map[word].search(sent):
                        entry_map[word]["例句"] = sent
                        unfilled.remove(word)
                        print(f"找到例句: {word} → {sent}")
                        break

    print(f"剩余未匹配到的单词数: {len(unfilled)}")

    # 4. 保存新的 JSON
    out_json_path = json_path.replace(".json", "_with_examples.json")
    with open(out_json_path, "w", encoding="utf-8") as fout:
        json.dump(word_list, fout, ensure_ascii=False, indent=2)

    print(f"已完成，保存到 {out_json_path}")

# 示例调用
sentences_adj_base("public/data/adj_base.json", "public/OpenSubtitles")
# Out:
# 初始需要填充例句的单词数: 18
# 找到例句: verheiratet → Wir waren verheiratet.
# 找到例句: genug → Von den restlichen Sechs hat nur einer eine Anlage, die groß genug ist, um diesen Hubschrauber für die Neulackierung zu verstecken.
# 找到例句: besonders → (Off) Als besonders ehrbar gelten die Patrizier - also der Stadtadel - und der Klerus.
# 找到例句: tot → Urin zum Beispiel, als aber auch von toten Menschen, von Leichen.
# 找到例句: mindestens → Ein Exemplar ist seit mindestens 200 Jahren im Privatbesitz der Familie.
# 找到例句: dagegen → Und keiner kann etwas dagegen tun.
# 找到例句: ungefähr → Aimée erahnte ungefähr, was Friedrich so bezauberte, aber sie hatte in Ihrem Leben gelernt, still zu leiden...!
# 找到例句: männlich → "...habe ich einen Trank, im Mai gekocht, von einer jungen und verspielten männlichen Schwalbe."
# 找到例句: perfekt → "Sie wissen, sie sind nicht gerade ein perfektes Beispiel mit ihrer Kleidung".
# 找到例句: weiblich → Weibliche Arbeiterinnen, Lenins Gefolgschaft (bei einem Arbeiterkongress)
# 找到例句: verwitwet → Die verwitwete Prinzessin von Hur.
# 找到例句: geschieden → Von einem geschiedenen...
# 找到例句: ledig → Er sagte mir, er sei praktisch ledig.
# 找到例句: gestreift → Aber sie haben mich nur gestreift.
# 找到例句: kariert → - Schwarz-weiß kariert?
# 找到例句: berufstätig → 33 Jahre alt, nicht berufstätig.
# 找到例句: gepunktet → Sie trägt ein gepunktetes Kleid.
# 找到例句: geblümt → Wär so 'ne richtige Junggesellenwohnung mit geblümten Vorhängen.
# 所有单词都已找到例句，提前结束！
# 剩余未匹配到的单词数: 0
# 已完成，保存到 public/data/adj_base_with_examples.json

# %% [markdown]
# ## for adj steigerung

# %%
import json
import os
import re
import random

def build_steigerung_patterns(entry):
    """
    传入一个形容词词条 entry（有 原型/比较级/最高级），返回所有变体的正则pattern。
    """
    # 所有“词干”原型，比较级，最高级
    stems = []
    for key in ["原型", "比较级", "最高级"]:
        v = entry.get(key)
        if v and v not in stems:
            stems.append(v)
    # 常见形容词词尾（规则可自行加/删）
    endings = ['', 'e', 'es', 'er', 'en', 'em', 'n', 's', 'ste', 'sten', 'ster', 'stes', 'ere', 'eren', 'erem', 'eres']
    patterns = []
    for stem in stems:
        patterns += [rf"\b{re.escape(stem)}{end}\b" for end in endings]
    # 合成大正则
    return re.compile('|'.join(patterns), flags=re.IGNORECASE)

def sentences_adj_steigerung(json_path, opensub_folder):
    # 1. 读取单词本 JSON
    with open(json_path, "r", encoding="utf-8") as f:
        word_list = json.load(f)

    # 2. 构建未被填充例句的词根集合，以及映射（词根 -> json entry 对象引用）
    unfilled = set()
    entry_map = {}
    pattern_map = {}

    for entry in word_list:
        if entry.get("例句", "") == "" and entry.get("原型"):
            # 用原型做唯一键
            word = entry["原型"]
            unfilled.add(word)
            entry_map[word] = entry
            pattern_map[word] = build_steigerung_patterns(entry)

    print(f"初始需要填充例句的单词数: {len(unfilled)}")

    # 3. 遍历 OpenSubtitles 的 txt 文件
    part_files = sorted(
        [f for f in os.listdir(opensub_folder) if f.startswith("part_") and f.endswith(".txt")],
        key=lambda x: int(x.split("_")[1].split(".")[0])
    )
    random.shuffle(part_files)

    for fname in part_files:
        if not unfilled:
            print("所有单词都已找到例句，提前结束！")
            break

        fpath = os.path.join(opensub_folder, fname)
        with open(fpath, "r", encoding="utf-8", errors="ignore") as fin:
            for line in fin:
                sent = line.strip()
                if not sent:
                    continue
                for word in list(unfilled):
                    # 使用正则支持全部词干变体匹配
                    if pattern_map[word].search(sent):
                        entry_map[word]["例句"] = sent
                        unfilled.remove(word)
                        print(f"找到例句: {word} → {sent}")
                        break

    print(f"剩余未匹配到的单词数: {len(unfilled)}")

    # 4. 保存新的 JSON
    out_json_path = json_path.replace(".json", "_with_examples.json")
    with open(out_json_path, "w", encoding="utf-8") as fout:
        json.dump(word_list, fout, ensure_ascii=False, indent=2)

    print(f"已完成，保存到 {out_json_path}")

# 示例调用
sentences_adj_steigerung("public/data/adj_steigerung.json", "public/OpenSubtitles")
# Out:
# 初始需要填充例句的单词数: 52
# 找到例句: jung → Er ist zu jung.
# 找到例句: weit → Und streckt den entgegengesetzten Arm weit vor.
# 找到例句: alt → Das ist normal in meinem Alter.
# 找到例句: schön → Schön, dass du mal mitgekommen bist.
# 找到例句: hoch → Höchstens November.
# 找到例句: fett → Kaum noch Fett dran.
# 找到例句: gemein → Das ist gemein.
# 找到例句: schlimm → Ist es was Schlimmes ?
# 找到例句: unglaublich → Das ist ja unglaublich.
# 找到例句: gesund → Er sagt, Sie sind wieder gesund.
# 找到例句: schwer → Paula hat's schwerer erwischt.
# 找到例句: eng → Und jetzt enger zusammen.
# 找到例句: dünn → Dünner Teig, wenig Zucker, viel Obst.
# 找到例句: heiß → (TV:) Also, was mich betrifft, ich würde den Bären im Freistaat willkommen heißen, wenn er sich entschließen würde, uns zu besuchen."
# 找到例句: warm → Bei mir wär's wärmer.
# 找到例句: bereit → In Bayern gilt bereits der Schießbefehl.
# 找到例句: schick → Meine Wähler schicken mir Drohbriefe.
# 找到例句: kalt → Also brachten die Franzosen uns in ein Gefängnis in den Pyrenäen, wo Ich mir eine Tuberkulose holte, weil es so kalt war.
# 找到例句: altmodisch → Aber er hält fest an der altmodischen Idee einer universellen Bruderschaft.
# 找到例句: hübsch → Ist das nicht hübsch?
# 找到例句: trocken → Und Sie beide bringen wir ins Trockene.
# 找到例句: bekannt → Man hat uns noch nicht bekannt gemacht.
# 找到例句: elegant → Eine sehr elegante Metapher, Monsieur Ngouta.
# 找到例句: stark → Nun, die Leber und Schenkel machen nicht mehr so mit, aber das Herz ist stark.
# 找到例句: scharf → Er ist so scharf wie Ihr Verstand.
# 找到例句: entspannt → Entspannte Musik
# 找到例句: speziell → Eine spezielle Diät.
# 找到例句: bunt → Es wird mir zu bunt!
# 找到例句: abhängig → Ich war abhängig, bin aber trocken.
# 找到例句: typisch → Das ist typisch für die Opposition!
# 找到例句: undenkbar → Das wäre vor einer Woche noch undenkbar gewesen.
# 找到例句: kühl → Ein kühles Bier ist mir lieber.
# 找到例句: dick → Der dicke Frank.
# 找到例句: nass → Auf nassem Boden.
# 找到例句: schlicht → Eine schlichte Zeremonie.
# 找到例句: regnerisch → Es ist regnerisch.
# 找到例句: schmutzig → Ich versuchte deshalb gut im Sport zu sein,... aber ich hasste es, schmutzig zu werden!
# 找到例句: heiter → Wie kannst du so was nur aus heiterem Himmel sagen?
# 找到例句: hässlich → Wir reden nicht über das hässliche was wir sehen.
# 找到例句: unabhängig → Während er im Knast war, nahm er an unabhängigen Fernklassen in
# 找到例句: kompliziert → Sie ist kompliziert.
# 找到例句: denkbar → Und zwar zum denkbar besten Zeitpunkt.
# 找到例句: formell → Ihr wolltet doch nichts Formelles.
# 找到例句: grell → Jetzt muss ich "meine Haare grell färben"... und dann nichts wie ab "zum Rave".
# 找到例句: neblig → Es war neblig.
# 找到例句: windig → - Es ist "windig".
# 找到例句: sonnig → Meist sonniges Wetter mit Temperaturen um fünf Grad...
# 找到例句: ungesund → Ich finde es destruktiv, ungesund.
# 找到例句: konservativ → Eher konservativ.
# 找到例句: bewölkt → Leider ist es heute bewölkt, doch es ist der letzte Tag und es erscheinen jede Menge Besucher im Yukata.
# 找到例句: glaublich → - UN-glaublich, was?
# 找到例句: spanned → Das war ein spanneder Weg, Jackson.
# 所有单词都已找到例句，提前结束！
# 剩余未匹配到的单词数: 0
# 已完成，保存到 public/data/adj_steigerung_with_examples.json

# %% [markdown]
# ## for noun obj

# %%
import json
import os
import re
import random

def strip_article(word):
    # 去掉 der/die/das (注意首字母大写或小写、前后空格)
    return re.sub(r'^(der|die|das|Der|Die|Das)\s+', '', word).strip()

def build_noun_pattern(entry):
    # 取出有效的单数和复数词根（去掉冠词）
    forms = []
    for key in ["单数", "复数"]:
        w = entry.get(key, '').strip()
        if w:
            w = strip_article(w)
            if w and w not in forms:
                forms.append(w)
    # 只匹配整个单词
    patterns = [rf"\b{re.escape(w)}\b" for w in forms]
    return re.compile('|'.join(patterns), flags=re.IGNORECASE)

def sentences_noun(json_path, opensub_folder):
    with open(json_path, "r", encoding="utf-8") as f:
        word_list = json.load(f)

    unfilled = set()
    entry_map = {}
    pattern_map = {}

    for entry in word_list:
        if entry.get("例句", "") == "":
            # 用“单数”去冠词作为唯一key
            key = strip_article(entry.get("单数", "")) or strip_article(entry.get("复数", ""))
            if key:
                unfilled.add(key)
                entry_map[key] = entry
                pattern_map[key] = build_noun_pattern(entry)

    print(f"初始需要填充例句的单词数: {len(unfilled)}")

    part_files = sorted(
        [f for f in os.listdir(opensub_folder) if f.startswith("part_") and f.endswith(".txt")],
        key=lambda x: int(x.split("_")[1].split(".")[0])
    )
    random.shuffle(part_files)

    for fname in part_files:
        if not unfilled:
            print("所有单词都已找到例句，提前结束！")
            break
        fpath = os.path.join(opensub_folder, fname)
        with open(fpath, "r", encoding="utf-8", errors="ignore") as fin:
            for line in fin:
                sent = line.strip()
                if not sent:
                    continue
                for word in list(unfilled):
                    if pattern_map[word].search(sent):
                        entry_map[word]["例句"] = sent
                        unfilled.remove(word)
                        print(f"找到例句: {word} → {sent}")
                        break

    print(f"剩余未匹配到的单词数: {len(unfilled)}")

    out_json_path = json_path.replace(".json", "_with_examples.json")
    with open(out_json_path, "w", encoding="utf-8") as fout:
        json.dump(word_list, fout, ensure_ascii=False, indent=2)

    print(f"已完成，保存到 {out_json_path}")

# 示例调用
sentences_noun("public/data/nomen_obj.json", "public/OpenSubtitles")
# Out:
# 初始需要填充例句的单词数: 595
# 找到例句: Arm → (Pickman) Die blutende Arterie im linken Arm ist das Schlimmste.
# 找到例句: Nacht → Gute Nacht, Dr. Greene.
# 找到例句: Minute → Prüfen und EKG in 10 Minuten wiederholen.
# 找到例句: Wolke → Keine Wolke zu sehen.
# 找到例句: Morgen → Bist du morgen da?
# 找到例句: Ball → Dein Ball braucht Luft.
# 找到例句: Couch → - Du hättest mir die Couch lassen sollen.
# 找到例句: Heizung → Ich hätte vielleicht die Heizung aufdrehen sollen.
# 找到例句: Kaffee → Gleich gibt's Kaffee.
# 找到例句: Loch → Und vorher frisst er dir ein Loch in die Magenschleimhaut.
# 找到例句: Bad → Geh du schon mal ins Bad.
# 找到例句: Telefon → (Telefon klingelt)
# 找到例句: Uhr → War doch richtig, 7:30 Uhr Yoga, nicht?
# 找到例句: Problem → - Weißt du, er hat Probleme.
# 找到例句: Arbeit → Susan, John, hier gibt es Arbeit.
# 找到例句: Jahr → Männlich, 40 Jahre, fiel aus 2 Meter Höhe aufs Gesäß.
# 找到例句: Name → - Wie ist Ihr Name, Sir?
# 找到例句: Krankenhaus → - Einem Krankenhaus?
# 找到例句: Vorsicht → Vorsicht, der ist angenäht, 100 % Rosshaar, gehört mir auch.
# 找到例句: Auge → - Ich muss Augen und Ohren untersuchen.
# 找到例句: Schmerz → - Haben Sie hier Schmerzen, Sir?
# 找到例句: Knie → - Die Knie hoch.
# 找到例句: Paar → Wir machen zur Sicherheit noch ein paar Röntgenaufnahmen.
# 找到例句: Hand → - Ist Ihre Hand ok?
# 找到例句: Weg → Ich gehe hier nicht weg.
# 找到例句: Sache → Die Sachen, die er anhat, sind mindestens $2.000 wert.
# 找到例句: Woche → Und Sie müssen 6 Wochen eine Schiene tragen.
# 找到例句: Handschuh → Passt die über meinen Handschuh?
# 找到例句: Finger → Wir röntgen diesen Finger, falls er gebrochen ist.
# 找到例句: Tasche → Vor lauter Angst um ihre Klamotten hat sie ihre Tasche vergessen.
# 找到例句: Job → Wer weiß, vielleicht bin ich ja im falschen Job.
# 找到例句: Freizeit → - Machen Sie das in Ihrer Freizeit.
# 找到例句: Zimmer → Und mit einem Praktikanten im Zimmer?
# 找到例句: Schule → Und in der Schule warst du auch immer das Unschuldslamm, nicht?
# 找到例句: Telefonnummer → Sie hat ihre Telefonnummer für den Notfallkontakt in der Chirurgie geändert.
# 找到例句: Unfall → - Wegen dem Unfall ihrer Tochter?
# 找到例句: Zeit → Das war nur eine Frage der Zeit.
# 找到例句: Ende → - Links am Ende des Flurs.
# 找到例句: Tag → (Kovac) Soviel ich weiß, den ganzen Tag.
# 找到例句: Schrank → Ich war's nicht, die das Ding in ihren Schrank getan hat.
# 找到例句: Körper → - Aus "Ich singe den Körper elektrisch."
# 找到例句: Film → Der Film, da kam das vor.
# 找到例句: Dialog → Ich liebe Fame. ich kann den Dialog auswendig.
# 找到例句: Raum → Raum 224, um 0800 wurde uns gesagt.
# 找到例句: Gebäude → Dies ist ein öffentliches Gebäude.
# 找到例句: Stress → Vielleicht wollen sie wissen, wie wir auf Stress reagieren.
# 找到例句: Mensch → Der Mensch ist da ja fast ein wildes Tier.
# 找到例句: Mund → Dann halt den Mund.
# 找到例句: Haar → (Lewis) Und die Schlangen krochen ihnen ins Haar und in den Mund!
# 找到例句: Wohnung → Irgendwo musste ich hin, bis ich eine neue Wohnung hatte.
# 找到例句: Thema → Können wir jetzt vielleicht mal das Thema wechseln?
# 找到例句: Basketball → Ich stehe mehr auf Basketball.
# 找到例句: Studium → - Die finanzieren mein Studium.
# 找到例句: Angst → Keine Angst?
# 找到例句: Land → Ich bin bereit, wenn mein Land mich braucht.
# 找到例句: Familie → - Patriotische Familie.
# 找到例句: Besuch → Ja, wir reden nicht darüber, wenn Besuch da ist.
# 找到例句: Fernseher → Er sitzt vor dem Fernseher und bringt sein Cholesterin auf über 400.
# 找到例句: Haus → Nicht Häuser, Kunstmaler.
# 找到例句: Menge → Eine Menge.
# 找到例句: Million → - 50 Millionen?
# 找到例句: Geld → - Großmutters Geld.
# 找到例句: Geschenk → Geschenke zu Weihnachten, genug zu essen.
# 找到例句: Kurs → - Ist hier der Kurs Sexuelle Belästigung?
# 找到例句: Auto → Er hat Probleme mit dem Auto.
# 找到例句: Schlüssel → Im Internat hatte ich oft den Schlüssel zu meinem Zimmer vergessen.
# 找到例句: Getränk → Süßigkeiten, Getränke.
# 找到例句: Stück → - Was ist das für ein Stück?
# 找到例句: Übung → Das Leben ist eine leere, hoffnungslose Übung voll
# 找到例句: Uni → Ich hatte als Nebenfach Englische Literatur an der Howard-Uni.
# 找到例句: Leben → Als wäre es ein bisschen dämlich, freiwillig unser Land mit seinem Leben zu verteidigen und schlecht dafür bezahlt zu werden.
# 找到例句: Monat → - Ein paar Monate.
# 找到例句: Treffen → Treffen passieren sollte.
# 找到例句: Sport → Ich dachte immer, Fechten wäre ein eleganter Sport, entschuldige.
# 找到例句: Schulter → Michael, sei ehrlich, hast du ihr heimlich über die Schulter gesehen, als sie den Schrank aufgemacht hat?
# 找到例句: Ohr → Die Ruhigen haben's faustdick hinter den Ohren.
# 找到例句: Wasser → - Stille Wasser sind tief.
# 找到例句: Grad → Die Wüste, 50 Grad im Schatten und keine Wolke am Himmel.
# 找到例句: Sonne → Ich musste wieder dahin, wo die Sonne sich wochenlang nicht blicken lässt.
# 找到例句: Regen → Bittere Kälte, dunkle Wolken und Regen mag ich manchmal lieber.
# 找到例句: Spiel → - Wir spielen ein Spiel, wie alt?
# 找到例句: Team → Er war im Lacrosse-Team.
# 找到例句: Kirche → An der Balustrade der Kirche, nach der Chorprobe.
# 找到例句: Preis → Du musst nur sagen, dass du älter warst als 11 und Carter kriegt den Preis.
# 找到例句: Englisch → Englisch oder Kroatisch?
# 找到例句: Text → (Lewis) Kannst du deinen Text noch?
# 找到例句: Frage → Sein oder nicht sein, das ist hier die Frage.
# 找到例句: See → Schicksals zu erdulden, oder sich waffnen gegen einen See von Plagen...
# 找到例句: Fuß → - Gehen wir zu Fuß, Gallant?
# 找到例句: Essen → Gehen wir was essen, ich hab 'nen Mordshunger.
# 找到例句: Beispiel → - Nun, das war doch wie ein Duell zum Beispiel.
# 找到例句: Bildschirm → Sie können auf dem Bildschirm sehen, dass es ein Junge ist?
# 找到例句: Antwort → Ihr seid hier nicht in einer Quizsendung, und für richtige Antworten bekommt ihr keinen Preis.
# 找到例句: Bein → Schwing dich auf die Beine.
# 找到例句: Computer → - Ich brauch den Computer.
# 找到例句: Park → Haben ihn im Park gefunden.
# 找到例句: Stunde → Alles, was mir fehlt, sind 12 Stunden Schlaf.
# 找到例句: Öl → Etwas Öl auf einem Wattebausch sollte zur Reinigung reichen.
# 找到例句: Nase → Achte drauf, dass die Nase frei ist.
# 找到例句: Streit → Nein, es war kein richtiger Streit.
# 找到例句: Unternehmen → Was passiert, wenn Sie gar nichts unternehmen?
# 找到例句: Spüle → Ich muss spülen.
# 找到例句: Glück → Das klappt nicht immer, aber in diesem Fall haben wir Glück.
# 找到例句: Hotel → Sie checkt in ein Hotel ein.
# 找到例句: Garten → Ein Nachbar fand die Mutter im Garten, das Kind noch auf der Schaukel.
# 找到例句: Golf → Nein, er spielt Golf.
# 找到例句: Sprache → - Versteht sie unsere Sprache?
# 找到例句: Alkohol → Ihr Atem riecht ziemlich nach Alkohol.
# 找到例句: Handy → (HANDY KLINGELT)
# 找到例句: Nummer → Hinterlassen Sie Ihre Nummer und wir rufen Sie an, falls er wieder auftaucht.
# 找到例句: Chip → Das kommt davon, wenn man zu viel Chips und Cheeseburger isst.
# 找到例句: Urlaub → - Ich werde bald etwas Urlaub nehmen.
# 找到例句: Wein → Bestimmt hat sie ein paar Schlaftabletten genommen, vielleicht mit Wein.
# 找到例句: Motorrad → Auto gegen Motorrad.
# 找到例句: Chinesisch → (SPRICHT CHINESISCH)
# 找到例句: Wand → Rausziehen, bevor du die Wand einreißt und ihn umbringst.
# 找到例句: Hund → Sie ist schlimmer als ein Hund, aber vielleicht hat sie ja was an der Blase.
# 找到例句: Fett → Ich will nicht gemein sein, aber die Mutter ist so fett wie ein Sumo-Ringer, nur nicht so gelenkig.
# 找到例句: Flugzeug → Also, entweder kaufe ich die Cessna oder zum gleichen Preis 2 Flugzeuge, die repariert werden müssen.
# 找到例句: Nachricht → - Ich hab dir Nachrichten hinterlassen.
# 找到例句: Fliege → Carter, du und ich fliegen nach Las Vegas.
# 找到例句: Kinn → - Kurzes Kinn, nach vorne gekippt.
# 找到例句: Hilfe → - Könnt ihr Hilfe gebrauchen?
# 找到例句: Pause → Gut, mach eine kleine Pause.
# 找到例句: Polizei → Die Air Force ist nicht die Polizei.
# 找到例句: Wort → Du wirst bestehen, wenn du mir dein Wort gibst, nicht klinisch zu arbeiten.
# 找到例句: Laden → - So mag ich den Laden.
# 找到例句: Hunger → Ich habe keinen Hunger.
# 找到例句: Brief → Der Brief
# 找到例句: Strand → - "Liebe ER-Gang, es ist 17:30 Uhr und ich liege am Strand.
# 找到例句: Mai → Elizabeth sitzt neben mir und trinkt Saft, ich bevorzuge die Mai Tais."
# 找到例句: Meer → Rachel stippt Ellas Zehen ins Meer, während sie sich aufmachen, die schönste Muschel zu suchen."
# 找到例句: Beruf → "Oft dachte ich, ich hätte einen anderen Beruf wählen oder eine Praxis eröffnen, also etwas Ruhigeres, Lukrativeres machen sollen.
# 找到例句: Salz → - Salz?
# 找到例句: Zucker → - Sein Zucker muss runter.
# 找到例句: Winter → Mir ist mindestens so kalt wie einem Schneemann im Winter.
# 找到例句: Wörterbuch → - Mir wurde mein Wörterbuch geklaut.
# 找到例句: Mittagessen → Sie waren beim Mittagessen.
# 找到例句: Brust → (Melissa) Meine Brust.
# 找到例句: Hals → - Das rechte Bein und mein Hals.
# 找到例句: Kopf → (Lewis) Kopf stillhalten.
# 找到例句: Bahn → - Ich bin mit der Bahn gekommen.
# 找到例句: Brötchen → Ich habe im Fernsehen eine Schneidemaschine gesehen, wo man das Brötchen in ein weißes Ding legt, einen Hebel betätigt, und schon wird es aufgeschlitzt, ganz ohne Messer.
# 找到例句: Maschine → Aber er sagte, die Typen seien Gauner und die Maschine tauge nichts.
# 找到例句: Ecke → Ich denke immer noch, er müsste jeden Moment um die Ecke kommen.
# 找到例句: Bauch → - CT von Bauch und Becken.
# 找到例句: Rechnung → Bitte alles auf eine Rechnung.
# 找到例句: Cola → - Cola.
# 找到例句: Liste → (Romano) Ich stehe ganz oben auf ihrer Liste.
# 找到例句: Jacke → - Schöne Jacke.
# 找到例句: Überraschung → Besonders die Überraschung am Ende hat mir gefallen.
# 找到例句: Tisch → Du hast verpasst, wie ich auf dem Tisch getanzt habe.
# 找到例句: Meeting → - So kann man zu keinem Meeting gehen.
# 找到例句: Tasse → Eine Tasse Kaffee.
# 找到例句: Frühstück → (Kellnerin) Es gibt jetzt Frühstück.
# 找到例句: Geburtstag → Es hat an meinem Geburtstag angefangen.
# 找到例句: Tür → Sonst wäre ich sicher nicht so dumm gewesen, ihm die Tür aufzumachen.
# 找到例句: Bett → Ich muss ins Bett.
# 找到例句: Nachmittag → Wird heute Nachmittag extubiert.
# 找到例句: Marmelade → Marmelade oder Pudding.
# 找到例句: Hamburger → Wird dieser Kerl wie ein Hamburger aussehen?
# 找到例句: Gerät → Dieses Gerät ist einfach nur sehr empfindlich, das ist alles.
# 找到例句: Schuh → - Warum habe ich diese Schuhe gekauft?
# 找到例句: Fisch → - Ist dein Fisch abgekratzt?
# 找到例句: Tee → Daraus wird Tee gemacht.
# 找到例句: Party → Klingt nach einer wilden Party.
# 找到例句: Butter → Das war ja wie Butter.
# 找到例句: September → Seit September nicht mehr.
# 找到例句: Büro → Abby, kommen Sie später in mein Büro?
# 找到例句: Flur → Wir schieben sie in den Flur, bis ein Bett frei wird.
# 找到例句: Bier → - Nur Bier und Bourbon.
# 找到例句: Ausbildung → - Meine Ausbildung beenden.
# 找到例句: Reise → - Das kommt von der Reise.
# 找到例句: Wochenende → Nur ein Wochenende.
# 找到例句: Kartoffel → - Mögen Sie Kartoffeln?
# 找到例句: Kühlschrank → Du solltest ihn an den Kühlschrank hängen.
# 找到例句: Cafeteria → - In der Cafeteria.
# 找到例句: Platz → Heute bin ich ständig am falschen Platz.
# 找到例句: Rezept → Hole die Laborwerte, schreib ein Rezept und ab mit ihr.
# 找到例句: Mittag → Hackbraten zum Mittag.
# 找到例句: Bild → - Schon gut, wir machen nur Bilder.
# 找到例句: Ausflug → Das wird wie ein Ausflug, nicht?
# 找到例句: Papier → Was habt ihr alle nur gegen Papier?
# 找到例句: Boden → - Darum lagen Sie auf dem Boden.
# 找到例句: Pizza → Wenn Sie mich nach meiner Henkersmahlzeit fragen, Pizza, bitte.
# 找到例句: Kleidung → Frauen ohne Kleidung zu sehen.
# 找到例句: Müll → Sie denken, ich spreche Müll, nicht wahr?
# 找到例句: Abend → Guten Abend, Miss Guishar.
# 找到例句: Teller → Ich weiß nicht, lch habe im Moment ziemlich viel auf meinem Teller, aber vielleicht in ein oder zwei Tagen.
# 找到例句: Kleid → Es ist an der Zeit, dass Lara ein richtiges erwachsenes Kleid trägt.
# 找到例句: Zahn → Mein ganzes Leben... als ob es aus mir herausgezogen wird, wie ein Zahn, Yury.
# 找到例句: Oper → Eine Oper dauert so lange wie sie dauert, Mutter.
# 找到例句: Hausaufgabe → Sie sollten Ihre Hausaufgaben machen abends not--
# 找到例句: Sofa → Auf einem schmierigen Sofa herumhüpfen!
# 找到例句: Mütze → Nimm deine Mütze ab!
# 找到例句: Hälfte → Barikofsky und Blanca machen die erste Hälfte, und ich bin nach der Pause dran.
# 找到例句: Vorname → Ihr Vorname?
# 找到例句: Geschäft → Ich berate Madame Guishar bei ihrem Geschäft.
# 找到例句: Fenster → Schau aus dem Fenster und singe das Lied.
# 找到例句: Politik → Pascha, du weißt, ich hasse Politik.
# 找到例句: Bäckerei → Sie befreien die Bäckerei!
# 找到例句: Brot → Brot, Land und Freiheit!
# 找到例句: Bewegung → Ganz Moskau ist in Bewegung!
# 找到例句: Foto → Ich mache Fotos!
# 找到例句: Rest → Du magst die Freuden des Lebens, der feine Wein und die hübschen Kleider und den ganzen Rest davon.
# 找到例句: Musik → [Gute Musik spielt]
# 找到例句: Kuchen → Kuchen!
# 找到例句: Lösung → Und es war meine eigene liebe Anna lvanovna, möge Gott ihre Seele ruhen lassen, wer sah, dass die Lösung direkt vor unserer Nase lag.
# 找到例句: Brille → Ich würde Sie bitten, Ihre Brille zu heben und zu Yury und Tonya zu trinken, das glückliche Paar.
# 找到例句: Himmel → Himmel!
# 找到例句: Zug → " Entweder gibt es überhaupt keine Züge
# 找到例句: Pass → Pass auf dich auf.
# 找到例句: Herd → Wir haben unseren eigenen Herd und alles.
# 找到例句: Werkstatt → Früher habe ich in der Werkstatt ihrer Mutter Kleider genäht.
# 找到例句: Stadt → Die nächste Stadt ist Jurjatin.
# 找到例句: Gemüse → Wir können Gemüse anbauen und uns selbst ernähren.
# 找到例句: Bestellung → Bestellungen von oben.
# 找到例句: Fluss → Das ist mein Fluss.
# 找到例句: Gesundheit → Gesundheit.
# 找到例句: Treppe → Nein, Sie würden sie nur verschütten und die Treppe spritzen.
# 找到例句: Bibliothek → Ich sah dich in der Bibliothek.
# 找到例句: Stift → Sauber wie ein neuer Stift.
# 找到例句: Osten → Nach Osten!
# 找到例句: Natur → Es ist nur Natur, Sasha.
# 找到例句: Universität → Mein Vater wurde gefragt zurück an die Universität von Moskau zu kommen.
# 找到例句: Norden → auf einer Liste, die später verlegt wurde... in einem der unzähligen Konzentrationslager im Norden.
# 找到例句: Tuch → 60 zum Ersten für das Tuch, das ihre Prachtmähne zusammenhielt.
# 找到例句: Saft → Wollen Sie Wasser oder Saft?
# 找到例句: Streifen → Durch Afrika streifen.
# 找到例句: Taxi → Man bekommt schwer ein Taxi da oben.
# 找到例句: Schlafzimmer → Sie lag betrunken im Schlafzimmer.
# 找到例句: Euro → Nur 10.000 Euro.
# 找到例句: Hobby → Meinungsforschung ist mein Hobby.
# 找到例句: Farbe → Farbe?
# 找到例句: Termin → Soll ich ohne festen Termin vorbeikommen?
# 找到例句: Gespräch → Ich hatte ein Gespräch mit dem reizenden Herrn Schrewe.
# 找到例句: Süden → Ein kindlicher Traum, ein Haus im Süden, ein Leben ohne Sorgen.
# 找到例句: Theater → Das Theater, das Sie bei uns erlebten, gab es auch bei Doblers.
# 找到例句: Märchen → Es könnte nötig werden, wenn der Anwalt weiter Märchen erzählt, damit seine Mandantin frei kommt.
# 找到例句: Vormittag → Aber den ganzen Vormittag hatte er Damenbesuch, seine Nachbarin.
# 找到例句: Adresse → Name, Adresse?
# 找到例句: Straße → Halteplatz Wilbacher Straße, sie nahm sich ein Taxi.
# 找到例句: Bahnhof → Unsere Kollegen vom Rauschgift beobachteten die Schließfächer am Bahnhof.
# 找到例句: Gericht → Sie verspielten alles Wohlwollen bei Gericht.
# 找到例句: Mittagspause → Ein hübsches Plätzchen für eine Mittagspause.
# 找到例句: Größe → Ungefähr Ihre Größe?
# 找到例句: Garage → Der Nachbar holte sein Auto aus der Garage.
# 找到例句: Person → Eine Person war hier.
# 找到例句: Käse → Was soll der Käse?
# 找到例句: Schreibtisch → Ihr Mann hatte eine Pistole im Schreibtisch.
# 找到例句: Spaziergang → Ich glaube außerdem die Geschichte mit dem Spaziergang nicht.
# 找到例句: Fitness → Sie war fast täglich im Fitness-Studio.
# 找到例句: Bank → Ich bringe es zur Bank.
# 找到例句: Buch → Über Morphium wird Buch geführt!
# 找到例句: Hemd → Er wollte sein verschwitztes Hemd wechseln.
# 找到例句: Gramm → Man braucht heute nur ein Millionstel Gramm einer Substanz.
# 找到例句: Einladung → Danke für die Einladung.
# 找到例句: Vertrag → Vertrag ist Vertrag!
# 找到例句: Heimat → Er sagte, wer keine Heimat hat, kann auch keine verlieren.
# 找到例句: Milch → Hast du Milch?
# 找到例句: Handtuch → Drücken Sie ein nasses Handtuch drauf, sonst gibt es eine Beule.
# 找到例句: Anzeige → Ich erstatte Anzeige wegen Mordes an Lara Frese und will dass Sie gegen Scholten ermitteln im Fall Cronen und die Haft für Seebach aussetzen.
# 找到例句: Eintrittskarte → Sie hatte eine Eintrittskarte.
# 找到例句: Post → Doch, klar, bei der Oper geht die Post ab.
# 找到例句: Hose → 1904 auf der Weltausstellung hätte ich mir fast in die Hose gemacht.
# 找到例句: Fahrkarte → Seine Abhängigkeit ist keine Fahrkarte zur Selbstverwirklichung.
# 找到例句: Apfelsaft → Weißt du noch, als ich dir Apfelsaft für Wein verkaufte?
# 找到例句: Toilette → Pfui auf die Toilette.
# 找到例句: Cent → Das macht 67 Cent.
# 找到例句: Radio → Aber von 1945 bis 1960 konnte man kein Radio oder Fernseher einschalten, ohne einen Werbespot von ihr zu hören.
# 找到例句: Reis → Wie wäre es mit Lamm und Reis?
# 找到例句: Garderobe → Habt ihr gesehen, wie groß ihre Garderobe ist?
# 找到例句: Richtung → Aber ich weiß nicht, in welche Richtung ich mich lehnen soll.
# 找到例句: Unterricht → Ich hab anschließend noch Stand-up-Comedy-Unterricht an der VHS.
# 找到例句: Ampel → Die Ampel ist grün.
# 找到例句: Rathaus → RATHAUS QUAHOG
# 找到例句: Kissen → Stewie, Kissen aufschütteln.
# 找到例句: Suppe → Ich mache seine Suppe heiß.
# 找到例句: Stuhl → Ich untersuchte meinen Stuhl auf Blut.
# 找到例句: Abendessen → Er war so dankbar, dass er uns alle zum Abendessen eingeladen hat.
# 找到例句: Tennis → Jeff spielt Tennis für Saint Genevieve High.
# 找到例句: Hochzeit → Du sagst ihm, du akzeptierst seinen Lebensstil und bereust, ihn bei einer Hochzeit als deine Tochter vorgestellt zu haben.
# 找到例句: Wohnzimmer → Wir gehen ins Wohnzimmer.
# 找到例句: Ei → Oh, Eier!
# 找到例句: Teppich → Der Teppich ist heiße Lava.
# 找到例句: Socke → Und das ist für die lila Hose und blauen Socken!
# 找到例句: Schild → Euer erstes Schild.
# 找到例句: Hut → Ich habe meinen Hut
# 找到例句: Stock → Und einen Stock Und eine Tasche voller Wunder
# 找到例句: Rock → Soll ich Detroit Rock City spielen und es mit Come Sail Away mischen?
# 找到例句: Pullover → Ich vergaß, den Pullover zurückzugeben, den Lois mir zu Weihnachten schenkte.
# 找到例句: Flughafen → QUAHOG FLUGHAFEN
# 找到例句: Ticket → Die Tickets.
# 找到例句: Fleisch → Los, Albert Hall, Fleisch mit Gemüse, Big Ben, Dave Clark Five,
# 找到例句: Schinken → Eier mit Schinken und tschüss, tschüss.
# 找到例句: Kilometer → Etwa 5.000 Kilometer in die Richtung.
# 找到例句: Oktober → Rolling Stone, Oktober 1972.
# 找到例句: Tüte → Ach, diese alberne Tüte.
# 找到例句: Balkon → Gut, und jetzt raus auf den Balkon und das Volk begrüßen.
# 找到例句: Konzert → Dein Fauxpas gestern Abend beim Konzert war so schlimm, dass ich einen Professor anrufen musste, um die passenden Worte zu finden.
# 找到例句: Kontakt → OK, bleiben wir in Kontakt?
# 找到例句: Eis → Holen wir uns ein Eis?
# 找到例句: Produkt → Ich werde es in Erwägung ziehen, dieses Produkt zu kaufen.
# 找到例句: Kino → Weißt du noch, im Kino?
# 找到例句: Insel → T.C., du fliegst mit dem Hubschrauber um die Insel, ich rede mit den schönen Frauen und Tattoo hält Ausschau nach den Kidnappern.
# 找到例句: Tor → Die Sicherheitsleute sollen mir das Tor aufschließen, Tattoo.
# 找到例句: Tankstelle → Vielleicht von der Tussi, die zur Tankstelle mitfahren wollte.
# 找到例句: Internet → - Wir kennen uns aus dem Internet.
# 找到例句: Süßigkeit → Er lockte mich mit Versprechungen und Süßigkeiten in den Park.
# 找到例句: Banane → Wie tief können Sie diese Banane in...?
# 找到例句: Rücken → Wasch mir bitte den Rücken.
# 找到例句: Schwimmbad → CVJM-SCHWIMMBAD
# 找到例句: Restaurant → DER GESCHMACK VON SIZILIEN RESTAURANT
# 找到例句: Sommer → - Sommer getan hast.
# 找到例句: Scheibe → Möchtest du auch eine Scheibe?
# 找到例句: Verspätung → Der Flug hatte Verspätung, da gab's die Kopfhörer umsonst.
# 找到例句: Sauna → In einer Sauna?
# 找到例句: Zahl → Wir zahlen.
# 找到例句: Trinkgeld → Gib dem Fahrer ein Trinkgeld.
# 找到例句: Durst → Ich habe richtig Durst...
# 找到例句: Ausgang → Alle Ausgänge werden bewacht.
# 找到例句: Satz → Bilde Sätze.
# 找到例句: Sushi → Um sie zu Sushi zu verarbeiten...
# 找到例句: Birne → Das frellt ebenfalls mit ihrer Birne, he.
# 找到例句: Nebel → Hm, irgendein Nebel.
# 找到例句: Orange → In der Mitte, orange Schweißleitung.
# 找到例句: Kultur → Diese Kultur muss dir merkwürdig vorkommen.
# 找到例句: Lebensmittel → Pilot, ich habe eine Tonne Lebensmittel zum Ausladen.
# 找到例句: Information → Eine beispiellos hohe Belohnung wird geboten für die Information, die zur Ergreifung von John Crichton führt.
# 找到例句: Mischung → Die Mischung ist fertig.
# 找到例句: Brücke → Sag Crichton, dass er auf die Brücke kommen soll.
# 找到例句: Tastatur → Crichton, dieses Gerät scheint durch eine Zahlenkombination an der Tastatur am Handschuh aktiviert zu werden.
# 找到例句: Form → Sie sind in der Lage, organische Hüllen in verschiedenen Formen zu bauen.
# 找到例句: Liter → Vielleicht fühlst du dich großzügiger, wenn du ein paar Liter eigenes Blut verloren hast.
# 找到例句: Ärmel → 1812, mach ihm diese Ärmel ab, schnell.
# 找到例句: Spezialität → Das ist unsere Spezialität.
# 找到例句: Spiegel → Hast du in letzter Zeit in den Spiegel gesehen?
# 找到例句: Küche → - Geh wieder in die Küche zurück.
# 找到例句: Datum → Plan A war, all ihre Daten zu löschen, sie auf Anfangsposition zurückzuschicken.
# 找到例句: Kreuzung → Kreuzung drei-lerg-acht.
# 找到例句: Linie → Diese ganz harte Linie, die Kommandantin Grayza da fährt, ändert so ziemlich alles.
# 找到例句: Tafel → Du hast die ganze Zeit nicht mehr auf die Tafel geschrieben.
# 找到例句: Generation → Generationen werden diesen Namen kennen.
# 找到例句: Parkplatz → Seid in meinen Parkplatz eingedrungen.
# 找到例句: Wind → Es sei denn, der Oger bekommt Wind von der Sache, dann haben wir Ärger.
# 找到例句: Etage → Etage, bitte.
# 找到例句: Erdgeschoss → Erdgeschoss.
# 找到例句: Jeans → Sind das Jeans?
# 找到例句: Begrüßung → Das muss irgendeine Begrüßung sein.
# 找到例句: Temperatur → Erhöh die Temperatur.
# 找到例句: Wärme → Sie werden unsere Wärme-Signaturen verbergen.
# 找到例句: Westen → Sie tragen kugelsichere Westen?
# 找到例句: Blume → Ich bin die Blume, ihr seid die Biene.
# 找到例句: Aufzug → Fährt der Aufzug nach unten?
# 找到例句: Weste → Sie tragen kugelsichere Westen?
# 找到例句: Salat → So dass Noranti uns verraten kann, wie man einen tollen Salat herstellt?
# 找到例句: Gepäck → Gepäck.
# 找到例句: Anzug → Netter Anzug.
# 找到例句: Pfeffer → da liegt der Hase im Pfeffer.
# 找到例句: Senf → Hast Senf und Zwiebeln mitgebracht?
# 找到例句: Wetter → Was ist mit diesem Wetter?
# 找到例句: Mehl → Sie besteht mehr aus Proteinpulver als Mehl.
# 找到例句: Schokolade → Ich habe mich bemüht, dass die Kuvertüre nach Schokolade schmeckt.
# 找到例句: Miete → Du hast die Miete für das Shuttle bezahlt, es gehört dir.
# 找到例句: Untergeschoss → Versiegle das Untergeschoss, bevor du nach oben gehst.
# 找到例句: Empfang → Empfang...
# 找到例句: Mantel → Wissen Sie, Ihr Mantel ist irgendwie braun.
# 找到例句: Zentrum → - Vielleicht ein Plätzchen im Zentrum.
# 找到例句: Schloss → Stärkere Schlösser, dickere Türen und alle bleiben da, wo sie sollen.
# 找到例句: Torte → Sie ist so glücklich, dass sie diese Torte tragen kann.
# 找到例句: Apfel → Sie hat meinen Apfel.
# 找到例句: Obst → Wenn wir frisches Obst bekommen, beißen wir einfach hinein.
# 找到例句: Fahrt → Einige Änderungen, und sie reichen für eine einfache Fahrt zu den Randplaneten.
# 找到例句: Berg → Ich war, wie gesagt, vor einigen Jahren hier, und stahl viel Knete vom Richter auf dem Berg, aber alles ging den Bach runter.
# 找到例句: Markt → Dafür wird man doch nicht auf dem Markt aufgestellt.
# 找到例句: Vitamin → Proteine, Vitamine und Kohlenhydrate wie im besten Gericht deiner Oma.
# 找到例句: Schnee → Der Schnee auf dem Dach ist zu schwer.
# 找到例句: Speisekarte → - Könnte Ich die Speisekarte haben?
# 找到例句: Regal → Wir könnten einfach hineingehen und den Lassiter von seinem Regal nehmen.
# 找到例句: Arbeitszimmer → In meinem Arbeitszimmer...
# 找到例句: Fabrik → - Dort gibt es Fabriken... und einige Ranches, falls du lieber an der Luft bist.
# 找到例句: Ofen → - Beim Ofen.
# 找到例句: Langeweile → Ich sehne mich nach Langeweile.
# 找到例句: Stempel → Dafür vielleicht der Stempel auf jedem Molekül der Fracht.
# 找到例句: Tomate → - Gib mir mal die Tomaten.
# 找到例句: Gewürz → - Wichtig sind die Gewürze.
# 找到例句: Top → Ich war Top-Student auf der besten Fakultät für Medizin des Osiris.
# 找到例句: Sehenswürdigkeit → Ich habe hier nicht angeheuert, um mir Sehenswürdigkeiten anzusehen.
# 找到例句: Museum → Es gibt schöne Museen.
# 找到例句: T-Shirt → Du schuldest mir ein T-Shirt.
# 找到例句: Zeh → - Deine Zehen sind im Sand.
# 找到例句: Zoo → Tischmanieren wie im Zoo.
# 找到例句: Zettel → Das stand auf dem Zettel, der mit einem Stein durch Gascoignes Fenster geworfen wurde.
# 找到例句: Fahrrad → Schließen Sie Ihre Fahrräder ab.
# 找到例句: Koffer → Dein Koffer steht im Flur.
# 找到例句: Arbeitszeit → Da kann ich über meine Arbeitszeiten froh sein.
# 找到例句: Fußball → Niemand lacht mehr, niemand weint mehr, niemand schreit, niemand spielt Fußball.
# 找到例句: Blatt → Blätter abstauben.
# 找到例句: Mayonnaise → Ich würde sie mit Mayonnaise einreiben.
# 找到例句: Waschmaschine → Wenn die Waschmaschine einen 25-minütigen Durchlauf hat und der Trackner 40 Minuten braucht, wann muss die zweite Ladung in die Maschine, damit sie um fünf tracken ist?
# 找到例句: Reservierung → Ich musste sonst was tun für die Reservierung im L''Espalier.
# 找到例句: E-mail → Ja, die E-Mail hat uns geschadet, aber Computer sind in fünf Jahren vergessen.
# 找到例句: Dose → Du öffnest die Dose und der Schaum läuft die Hand runter.
# 找到例句: Umzug → Der Umzug fällt aus.
# 找到例句: Karotte → Wo wart ihr heute Nacht, als ich eine Schlaftablette in eine Karotte stecken wollte?
# 找到例句: Maus → Du schuldest mir zehn Mäuse.
# 找到例句: Diät → Niles ist nach der OP auf Diät und wir helfen ihm.
# 找到例句: Verkehr → Nach dem Verkehr.
# 找到例句: Gymnastik → Ich glaube. dass Diät und Gymnastik Ihr Problem beheben.
# 找到例句: Parkhaus → Sie sind eindeutig im Parkhaus.
# 找到例句: Ketchup → Da klebt eine platte Ketchup-Tube dran fest,
# 找到例句: Keller → Dein Vater braucht deine Hilfe im Keller.
# 找到例句: Krawatte → Das mit der Krawatte in der Bandsäge soll sich nicht wiederholen.
# 找到例句: Juli → Juli hat er mit Problemkindern am Flussufer aufgeräumt.
# 找到例句: Halstuch → Meinen Sie vielleicht Halstücher?
# 找到例句: Packung → Eine volle Martin-Crane-Packung vergisst keine.,
# 找到例句: Februar → Februar 1993.
# 找到例句: Hochhaus → Sie wollten vom Hochhaus springen, falls Ihre Frau Sie verlässt.
# 找到例句: Bus → -Die Busse, die Bobbys, die Pubs,
# 找到例句: Spaghetti → Ich mache uns eine Dose Spaghetti auf.
# 找到例句: Stau → Stau auf der Strecke nach Northgate.
# 找到例句: Soße → Und rühren Sie es nicht unter die Soße.
# 找到例句: Keks → Ich habt euch um eine Hausregel gestritten und dann Kekse gegessen.
# 找到例句: Dom → Warte, ich hole den Dom.
# 找到例句: Amt → Er wollte das Amt schon immer, aber ich hätte nie gedacht, dass er so weit geht.
# 找到例句: Kostüm → -Soll das Kostüm mir Angst machen?
# 找到例句: Kakao → Entschuldigt mich, ich brauche meinen Kakao.
# 找到例句: Yoga → -Ich habe eine Freundin beim Yoga.
# 找到例句: Teig → Teig, Füllung und Baiser.,
# 找到例句: Training → Das harte Training, die Haltung, die Buchstabier-Diät.
# 找到例句: Badezimmer → - Wir sind im Badezimmer!
# 找到例句: Café → Äh, Pauls Café.
# 找到例句: Beilage → - Was gibt es als Beilage?
# 找到例句: Mozzarella → Ich weiß da ein Lokal, das Mozzarella-Sticks und Jalapeno-Poppers serviert.
# 找到例句: Menü → Ich möchte über Ihr Menü zu sprechen.
# 找到例句: Kindergarten → Emma ist in den Kindergarten.
# 找到例句: November → November 1968.
# 找到例句: Kalender → Für alle, die nicht in den Kalender gesehen haben, heute ist mein Stichtag.
# 找到例句: Paprika → Okay, hier eine dieser Paprika.
# 找到例句: Alltag → Es ist schon schlimm, dich im Alltag nie zu sehen, aber an Weihnachten...
# 找到例句: Sahne → Himbeeren und noch mal Löffelbiskuits, dann Rindfleisch mit Erbsen, Sahne.
# 找到例句: Wurst → Wurst, das Eis und Limonen.
# 找到例句: Kilo → Ich habe noch einige Kilo von der letzten Urlaubsreise.
# 找到例句: Himbeere → Himbeeren, mehr Löffelbiskuits, sautierten Rindfleisch mit Erbsen und Zwiebeln.
# 找到例句: Steak → Risotto mit rasierten truffIes und die Rippe Steak Mit der golden chantereIIes und die BordeIaise Sauce ...
# 找到例句: Hauptstadt → - Wie heißt die Hauptstadt Kolumbiens?
# 找到例句: Sessel → Ok, und wie werden wir nun diesen Sessel los?
# 找到例句: Zutat → Ich mischte die Zutaten, Ich habe sie in den Ofen, ich nahm sie heraus.
# 找到例句: Nudel → Dann wäre ein neuer Pudel eben ein Nudel.
# 找到例句: Marke → Wir, äh, tragen nur ganz zufällig dieselbe Marke.
# 找到例句: Frühling → Dann sollten Sie im Frühling kommen, da ist es herrlich.
# 找到例句: Nachname → Ok, und mit Nachnamen?
# 找到例句: Gitarre → - Ich spiele ein wenig Gitarre.
# 找到例句: Wanderung → Sie probably also hatte die Klavierlehrerin Wanderung mit den Händen.
# 找到例句: Traumberuf → Es ist ihr Traumberuf.
# 找到例句: Gurke → - Sag mal, sind da etwa Gurken drauf?
# 找到例句: Thunfisch → Falls jemand hier Buch führen sollte, ich werde nie wieder Thunfisch essen.
# 找到例句: Orangensaft → Na ja, und nun hab ich zu Orangensaft mit Kalzium gegriffen.
# 找到例句: Kleiderschrank → Ich habe nicht versucht zu öffnen Ihrem Kleiderschrank, das schwöre ich.
# 找到例句: Fitnessstudio → Vielleicht I'll ins Fitnessstudio.
# 找到例句: Dezember → Dezember 1999 geschah.
# 找到例句: Müsli → JUNGGESELLEN-MÜSLI
# 找到例句: Hähnchen → HÄHNCHEN, SCHMALZ, SALZ
# 找到例句: Januar → JANUAR 2000 12:30 UHR
# 找到例句: Gasse → Sie wurde in einer Gasse ungefähr zwei Blocks von hier erstochen.
# 找到例句: Jahreszeit → Mann, ich hasse diese Jahreszeit.
# 找到例句: Kälte → Er kann Schwindel, Kälte oder Übelkeit hervorrufen.
# 找到例句: Bluse → Hab ich deine Bluse ruiniert?
# 找到例句: Notausgang → Sieh's ein Dick, es gibt keinen Ausweg für dich, keinen Notausgang, keinen Spielraum mehr.
# 找到例句: Zitrone → Ich kann nichts dafür, dass dich Puppe auspresst wie eine Zitrone.
# 找到例句: Deutsch → Du sprichst gut Deutsch.
# 找到例句: Herbst → Im Herbst isst man eine Martinsgans.
# 找到例句: Kantine → Ist das Essen in der Kantine immer noch so schlecht?
# 找到例句: Schnitzel → Ein Schnitzel.
# 找到例句: Mineralwasser → Ein Mineralwasser.
# 找到例句: Supermarkt → "ICH geh einkaufen im Supermarkt und nicht DU!"
# 找到例句: Autobahn → Leider sind die Planungskosten für die Autobahn Schweden-Norwegen und für die Erschließung des Industriegebietes gestiegen.
# 找到例句: Lampe → Es ist wegen der Lampen vor der Tür.
# 找到例句: Ernährung → Richtige Ernährung ist sehr wichtig.
# 找到例句: Heimatland → Sie werden in Ihr Heimatland ausgewiesen.
# 找到例句: Juni → Juni aus Ungarn illegal bei uns eingereist.
# 找到例句: August → August haben die Behörden Sie wieder nach Ungarn abgeschoben.
# 找到例句: Quadratmeter → Aber auch dann verkauf i keinen Quadratmeter für eure depperten Pferde!
# 找到例句: Terrasse → Mit einer Terrasse!
# 找到例句: Kinderzimmer → Kinderzimmer 1, 2, 3 oder 4!
# 找到例句: Unterhose → Ich kann doch nicht in der Unterhose aufs Gericht!
# 找到例句: Knoblauch → Direkt weg vom Säbelfisch mit Knoblauch-Kruste.
# 找到例句: Bleistift → Das sind die besten Bleistift-spitzer, die es gibt.
# 找到例句: Möbel → Aber ich hatte mehr Möbel.
# 找到例句: Drucker → Digital sausen jetzt die virtuellen Buchstaben durch Drähte, Setzcomputer und Drucker.
# 找到例句: Verpflegung → Miete, Verpflegung, Kopfkissengebühr, die Handschuhe, die du wolltest, Prinzessin.
# 找到例句: Portemonnaie → Portemonnaies und Wertsachen hier rein.
# 找到例句: März → März.
# 找到例句: Lieblingsessen → Sie haben dein Lieblingsessen:
# 找到例句: Joghurt → -Ich hole einen Joghurt.
# 找到例句: Sportplatz → Sie teilen Gesundheitsformulare aus, und Sie melden sich am Sportplatz.
# 找到例句: Würfel → Einen Würfel.
# 找到例句: Mais → Kartoffel, Mais, blauer Mais, Sour Cream und Zwiebel,
# 找到例句: Ferien → Die Ferien sind vorbei.
# 找到例句: Kalorie → Wiederholen verbrennt Kalorien.
# 找到例句: Umkleidekabine → Malcolm, du stinkst wie eine Umkleidekabine.
# 找到例句: Traube → Ich wollte Traube.
# 找到例句: Nachttisch → Und ist Trudys Foto auf dem Nachttisch?
# 找到例句: Limonade → - Lass sie Limonade kaufen.
# 找到例句: Limo → Kaufen Sie Limo.
# 找到例句: Pfanne → Ein Steak in der Pfanne ist eine ordentliche Mahlzeit.
# 找到例句: Notizblock → Ist das ein Notizblock in Ihrer Tasche?
# 找到例句: Hausnummer → Und 530, das ist keine Hausnummer.
# 找到例句: Ordner → Ja, ich hatte einen extra Ordner.
# 找到例句: Postleitzahl → Bald haben Sie eine eigene Postleitzahl.
# 找到例句: Sandale → Eine Sandale Größe 40.
# 找到例句: Haltestelle → Ich besuchte eine Freundin und habe meine Haltestelle verpasst.
# 找到例句: Handynummer → Ich hab die Festnetznummer, Piepser, Handynummer.
# 找到例句: Armbanduhr → Sehen Sie hier eine Armbanduhr?
# 找到例句: Bewerbungsgespräch → Und da bekam ich für heute Morgen ein Bewerbungsgespräch.
# 找到例句: U-Bahn → Auf dem Weg zur U-Bahn komm ich vorbei.
# 找到例句: April → April 1991, obwohl ich nur verschriebene Erkältungsmedikamente genommen hatte.
# 找到例句: Fremdsprache → Ich unterrichte Englisch als Fremdsprache im Lawrence Center for Learning.
# 找到例句: Büroarbeit → -Büroarbeit?
# 找到例句: Friseursalon → Victoria war eine Stylistin im Friseursalon meiner Frau, die meine Frau überzeugt hat, sie sei krankhaft fettleibig, was sie nicht ist.
# 找到例句: Lieblingsfarbe → Was ist deine Lieblingsfarbe?
# 找到例句: Straßenbahn → "In Rhode Island darf man Gurkensaft nicht auf eine Straßenbahn werfen.
# 找到例句: Panne → Schaut mal, auf zehn Uhr hat einer eine Panne.
# 找到例句: Rosine → Mit Rosinen!
# 找到例句: Tofu → Es schmeckt wie Hühnerfleisch, ...- .. ist aber reines Tofu!
# 找到例句: Passnummer → Aber die Passnummer vom Steinerfehlt.
# 找到例句: Schal → Ich habe schon zwei Schals, eine Wolldecke und diese Ding hier gemacht.
# 找到例句: Quark → Ein redlicher Politiker ist wohl so schwer zu finden, wie ein Quark im Dreiecksnebel.
# 找到例句: Metzgerei → Dem Vater gehörte seit Jahren eine Metzgerei.
# 找到例句: Wohnort → Mit der Unterstützung der Gemeinde und allen Bürgern... werden wir aus Farmington einen sicheren Wohnort machen.
# 找到例句: Sommerferien → Aber nach den Sommerferien hat er aufgehört, zu schreiben.
# 找到例句: Jugendherberge → Wieso gehen wir nicht in die Jugendherberge?
# 找到例句: Fundbüro → - Bin ich das Fundbüro?
# 找到例句: Gardine → Ich war in der Küche und zählte die Maiskolben auf der Gardine... als jemand an der Tür klingelte.
# 找到例句: Margarine → Zwei Essensmarken und eine Bombenhülse mit Margarine.
# 找到例句: Radtour → Also wird doch nichts aus unserer Radtour durch Italien.
# 找到例句: Pommes frites → Ich nehme 'n "Chubby Cheeseburger" mit allem Drum und Dran, mittelgroße Pommes Frites und 'ne Cola.
# 找到例句: Kochbuch → Ein Rezept aus dem Kochbuch.
# 找到例句: Hosenanzug → Nein, Mom, ich hab meinen Laura-Bush-Hosenanzug darunter an.
# 找到例句: Tacker → Ein Tacker!
# 找到例句: Salami → Wer will die letzte Scheibe Salami?
# 找到例句: Apfelkuchen → Ich hob Ihnen Apfelkuchen auf!
# 找到例句: Familienname → Der Familienname ist Conlon.
# 找到例句: Verabschiedung → Tut mir leid, dass ich nicht runterkommen kann zur Verabschiedung, aber ich bin damit beschäftigt, nutzlosen Kram zu erfinden.
# 找到例句: Pfannkuchen → Aber jemand hat mir zu viele Pfannkuchen gemacht... die muss ich jetzt erstmal abschlafen.
# 找到例句: Stereotyp → Ich bin kein Stereotyp, ok?
# 找到例句: Öffnungszeit → Ich sage dir bald die neuen Öffnungszeiten.
# 找到例句: Flöte → ♪ Flöten und Trommeln
# 找到例句: Stadtplan → Oh, ein Stadtplan.
# 找到例句: Radiergummi → Mein Radiergummi ist weg.
# 找到例句: Ananas → Eher als Schweinefleisch süß-sauer mit Ananas.
# 找到例句: Sportart → Amerikanische oder englische Sportarten?
# 找到例句: Vokabel → Sind das Vokabeln?
# 找到例句: Bürostuhl → Ich weiß nicht, wo was ist, wie was funktioniert, die Computer, die Telefone, nicht mal mein Bürostuhl.
# 找到例句: Muttersprache → {\cHFFFFFF}{\cHFF409B} Sie streiten sich in ihrer {\cHFFFFFF}{\cHFF409B} türkischen Muttersprache.
# 找到例句: Dattel → {\cHFFFFFF}{\cHFFFF00} Was kosten die Datteln?
# 找到例句: Brokkoli → Oh ja, da sind sie ja, unter dem Brokkoli!
# 找到例句: Trainingsanzug → Der Trainingsanzug ist klasse.
# 找到例句: Föhn → Föhn geht an.
# 找到例句: Konferenzraum → Der Anruf kam aus dem Konferenzraum seines New Yorker Büros.
# 找到例句: Bücherregal → Ich denke, zumindest sind ein paar Bücherregale für die anderen Kunden übrig geblieben.
# 找到例句: Fahrplan → Hätte auf den Fahrplan achten sollen und die Verkehrsnachrichten.
# 找到例句: Allee → Dort bauen wir eine Allee mit Statuen, die wir "Allee mit Statuen" nennen.
# 找到例句: Kohlrabi → Na ich gehe und koche die gefüllten Kohlrabi fertig.
# 找到例句: Locher → das Knie lochen lassen wollte und dazu kam es nur deshalb nicht, weil der Kutscher, als sie ihm das Knie zeigte, sie lieber umsonst fahren ließ, als den Locher zu entwürdigen.
# 找到例句: Sekretariat → Ab ins Sekretariat und den Status überprüfen.
# 找到例句: Kiwi → Es schmeckt wie eine Kiwi.
# 找到例句: Hostel → "Saw", "Hostel", "Hackbeil".
# 找到例句: Lesesaal → Das ist 'n Restaurant, kein verdammter Lesesaal.
# 找到例句: Roulade → Rouladen?
# 找到例句: Herberge → Ich wohne in einer Herberge.
# 找到例句: Mandarine → Und Mandarinen.
# 找到例句: Aufenthaltserlaubnis → Wegen Beihilfe und Fluchthilfe für Personen ohne Aufenthaltserlaubnis.
# 找到例句: Besprechungsraum → Ich sehe dich um 7 Uhr im Besprechungsraum.
# 找到例句: Sprachkurs → Willst du einen Sprachkurs machen?
# 找到例句: Krafttraining → Krafttraining.
# 找到例句: Büroraum → Als wir Sie festnahmen, habe ich die Büroräume gesehen.
# 找到例句: Wochenmarkt → So ein Schwachkopf, der auf dem Wochenmarkt Karaoke singt und jeden Freitag zur Scharade einlädt.
# 找到例句: Arbeitstreffen → Michael hatte gestern Abend ein Arbeitstreffen, wo wir hingingen.
# 找到例句: Fußgängerzone → Ich kenne die Fußgängerzone.
# 找到例句: Reisetasche → Ich habe deine Reisetasche gepackt.
# 找到例句: Buslinie → Die Fahrgäste mögen doch die andere Buslinie benutzen am Ortsausgang.
# 找到例句: Arbeitsschuh → Ohne meinen Overall und meine Arbeitsschuhe mach ich gar nichts.
# 找到例句: Fahrradladen → Außerdem dieser Typ lungert seit Tagen vor dem Fahrradladen und vor der Wohnung herum.
# 找到例句: Stehlampe → (stammelt) Aber nach 'ner gewissen Zeit und Dauer, da wird eben eine Stehlampe auch mal wieder zu einer Hänge...
# 找到例句: Deutschkurs → Die Stadt bietet Deutschkurse für Ausländer an.
# 找到例句: Sprachschule → Geh damit zum Rauschgiftdezernat, aber für unsere Ermittlungen spielt diese Sprachschule keine Rolle.
# 找到例句: Flashe → Ich habe davon geträumt, 9a+ zu flashen, seit ich 18 Jahre alt war.
# 找到例句: Schreibtischstuhl → Ich repariere meinen Schreibtischstuhl.
# 找到例句: Schokoladencreme → Süßen Brei, Würstchen mit Salat, Schokoladencreme...
# 找到例句: Deutschunterricht → Und dein Deutschunterricht?
# 找到例句: Yoga-Matte → Doch Tanja wird auch morgen wieder um neun an Sigrids Yoga-Matte stehen.
# 找到例句: Volleyballtraining → Sie bleibt länger zum Volleyballtraining.
# 找到例句: Fahrradgeschäft → Gesucht wird ein Typ, der heute einen jungen Mann getötet und anschließend ein Fahrradgeschäft überfallen hat.
# 剩余未匹配到的单词数: 1
# 已完成，保存到 public/data/nomen_obj_with_examples.json

# %% [markdown]
# ## for noun people

# %%
import json
import os
import re
import random

def strip_article(word):
    # 去掉 der/die/das/Das/Die/Der
    return re.sub(r'^(der|die|das|Der|Die|Das)\s+', '', word).strip()

def build_person_pattern(entry):
    # 汇总所有要匹配的形式（单数/复数/男女），都去掉冠词
    fields = ["单数男", "复数男", "单数女", "复数女"]
    forms = []
    for key in fields:
        w = entry.get(key, '').strip()
        if w:
            w = strip_article(w)
            if w and w not in forms:
                forms.append(w)
    patterns = [rf"\b{re.escape(w)}\b" for w in forms]
    if patterns:
        return re.compile('|'.join(patterns), flags=re.IGNORECASE)
    else:
        return None

def sentences_nomen_people(json_path, opensub_folder):
    with open(json_path, "r", encoding="utf-8") as f:
        word_list = json.load(f)

    unfilled = set()
    entry_map = {}
    pattern_map = {}

    for entry in word_list:
        if entry.get("例句", "") == "":
            # 找到第一个非空的字段，去掉冠词做key
            key = None
            for field in ["单数男", "复数男", "单数女", "复数女"]:
                candidate = strip_article(entry.get(field, ""))
                if candidate:
                    key = candidate
                    break
            if key:
                unfilled.add(key)
                entry_map[key] = entry
                pattern = build_person_pattern(entry)
                if pattern:
                    pattern_map[key] = pattern

    print(f"初始需要填充例句的单词数: {len(unfilled)}")

    part_files = sorted(
        [f for f in os.listdir(opensub_folder) if f.startswith("part_") and f.endswith(".txt")],
        key=lambda x: int(x.split("_")[1].split(".")[0])
    )
    random.shuffle(part_files)

    for fname in part_files:
        if not unfilled:
            print("所有单词都已找到例句，提前结束！")
            break
        fpath = os.path.join(opensub_folder, fname)
        with open(fpath, "r", encoding="utf-8", errors="ignore") as fin:
            for line in fin:
                sent = line.strip()
                if not sent:
                    continue
                for word in list(unfilled):
                    if pattern_map[word].search(sent):
                        entry_map[word]["例句"] = sent
                        unfilled.remove(word)
                        print(f"找到例句: {word} → {sent}")
                        break

    print(f"剩余未匹配到的单词数: {len(unfilled)}")

    out_json_path = json_path.replace(".json", "_with_examples.json")
    with open(out_json_path, "w", encoding="utf-8") as fout:
        json.dump(word_list, fout, ensure_ascii=False, indent=2)

    print(f"已完成，保存到 {out_json_path}")

# 示例调用
sentences_nomen_people("public/data/nomen_people.json", "public/OpenSubtitles")
# Out:
# 初始需要填充例句的单词数: 63
# 找到例句: Kind → Kinder?
# 找到例句: Vater → Sie gibt dauernd mit dem Cadillac von ihrem Vater an.
# 找到例句: Eltern → Wisst ihr, Mama und Dad, ihr seid wirklich die besten Eltern, die ein Mädchen haben kann.
# 找到例句: Junge → Tapferes Mädchen, Peg!
# 找到例句: Sohn → -Wir haben dir unsere Tochter anvertraut.
# 找到例句: Freund → Maddy ist eine deiner besten Freundinnen.
# 找到例句: Bruder → Ich habe mit deiner Schwester zu reden.
# 找到例句: Leute → Amüsiert euch gut, ihr jungen Leute!
# 找到例句: Kollege → Zusammen mit ihren Kollegen.
# 找到例句: Designer → Designer:
# 找到例句: Gast → Und das ist unser Gast.
# 找到例句: Arzt → - Zum Arzt hören!
# 找到例句: Mitarbeiter → Im Namen aller Überlebenden der Mitarbeiter des Museums,
# 找到例句: Nachbar → Hass Nachbar hasse alle, hasse mich!
# 找到例句: Chef → Sie konnten gerade bestellen, als Chef der Sicherheit.
# 找到例句: Opa → (Die Woche war fürchterlich, Oma.)
# 找到例句: Polizist → Nach vielen Jahren ... der Abschluss viele feine Polizisten, der Staat sagt ... kann es sich nicht länger leisten zwei Polizisten Akademien.
# 找到例句: Koch → Er konnte mit einem guten Sushi-Koch.
# 找到例句: Lehrer → -Sind Sie ein Lehrer?
# 找到例句: Friseur → Und wer ist Ihr Friseur?
# 找到例句: Mitbewohner → Er ist dein Mitbewohner.
# 找到例句: Bekannte → -Sie bekannte sie für zwei, drei Jahre?
# 找到例句: Fahrer → ... Reicht ihm das Ticket, und der Fahrer sagte -
# 找到例句: Kellner → Kellner, Runde Getränke.
# 找到例句: Großvater → Besuch meine Großmutter in Spanien!
# 找到例句: Tourist → Dort gibt es auch Touristen.
# 找到例句: Geschwister → Meine Geschwister sind da und deren Kinder.
# 找到例句: Onkel → Mit dem Onkel!
# 找到例句: Sekretär → Ich arbeite als Sekretärin, das ist nicht sehr interessant!
# 找到例句: Babysitter → Wir machen die Strategie, ihr seid Babysitter.
# 找到例句: Deutsche → * Deutsche Nationalhymne *
# 找到例句: Student → (Radio) ... der demonstrierenden Studenten und der Polizei dauern noch an.
# 找到例句: Anwalt → Dein Anwalt ist dir sehr ergeben.
# 找到例句: Kunde → Ihr Kunde wartet im letzten Zimmer auf der linken Seite.
# 找到例句: Krankenpfleger → Dann werd Krankenschwester.
# 找到例句: Vegetarier → Sind deine Gangsterfreunde Vegetarier?
# 找到例句: Bäcker → Der Bäcker hat gerufen.
# 找到例句: Verkäufer → Du hast einen Laden überfallen... und den armen Verkäufer zusammengeschlagen.
# 找到例句: Cousin → Ja, so ist es bei meiner Cousine.
# 找到例句: Bauer → Königin besiegt Springer, Turm besiegt Königin, Bauer besiegt Turm.
# 找到例句: Neffe → Wie ich von meiner Nichte höre, habt Ihr sie dazu überredet, sie von Euch nackt malen zu lassen.
# 找到例句: Europäer → Werden auch nicht krank in dieser Hitze, wie Europäer.
# 找到例句: Fotograf → Wenn ein Fotograf an den Set kommt und nicht weiß, was er will, dauert das ewig.
# 找到例句: Pilot → Karl Haffner, 35 Jahre, Dozent für Kunstgeschichte, früher Pilot bei der Bundeswehr.
# 找到例句: Mieter → Der neue Mieter, ja?
# 找到例句: Schüler → Ich war seine beste Schülerin.
# 找到例句: Enkelkind → Setz die Maske dort auf, wo du Enkelkinder erschrecken willst!
# 找到例句: Großeltern → Das könnten unsere Großeltern sein.
# 找到例句: Verwante → Sie ist bei Verwandten in Charleston.
# 找到例句: Ingenieur → Ich bin ein Ingenieur aus Nicaragua.
# 找到例句: Zwillingsbruder → Es gibt also keine Zwillingsschwester Buffy?
# 找到例句: Einzelkind → Ich bin ein Einzelkind.
# 找到例句: Erzieher → Ich bin Erzieher.
# 找到例句: Informatiker → Unter dem Ayatollah-Regime braucht man keine Informatiker.
# 找到例句: Enkelsohn → Er ist Ihr Enkelsohn.
# 找到例句: Architekt → Architekten...
# 找到例句: Interessent → Na ja, es sind so wenig Interessenten, da dachte ich, vielleicht könntest du ein wenig werben bei den Müttern?
# 找到例句: Elektriker → Aber meine Nachbarin braucht einen Elektriker.
# 找到例句: Auszubildende → Wer ist die Auszubildende?
# 找到例句: Kursteilnehmer → Das würde die Frau Weinheim ihre Kursteilnehmer jetzt fragen.
# 找到例句: Bankkaufmann → Wenn sie hier schon Bankkauffrauen einstellen, warum müssen sie sich nicht bescheiden kleiden?
# 找到例句: Fahrradhändler → Es kommt vom Fahrradhändler.
# 找到例句: Kfz-Mechatroniker → Ausbildung zur Kfz-Mechatronikerin.
# 所有单词都已找到例句，提前结束！
# 剩余未匹配到的单词数: 0
# 已完成，保存到 public/data/nomen_people_with_examples.json

# %% [markdown]
# ## for verb base

# %%
import json
import os
import re
import random

def build_verb_patterns(entry):
    """
    给定一个动词 entry，返回涵盖主流变体的正则 pattern。
    """
    forms = set()
    # 1. 原型
    if entry.get("原型"):
        forms.add(entry["原型"].strip())
    # 2. 现在三单
    if entry.get("现在(第三人称单数)"):
        forms.add(entry["现在(第三人称单数)"].strip())
    # 3. 过去三单
    if entry.get("过去(第三人称单数)"):
        forms.add(entry["过去(第三人称单数)"].strip())
    # 4. 完成分词（如 "hat geholfen"，提取最后一个单词）
    if entry.get("完成"):
        parts = entry["完成"].strip().split()
        if len(parts) >= 2:
            forms.add(parts[-1])
        else:
            forms.add(entry["完成"].strip())
    # 常见动词结尾
    endings = ['', 'e', 'st', 't', 'en', 'te', 'test', 'tet', 'ten', 'et']
    patterns = []
    for f in forms:
        for end in endings:
            patterns.append(rf"\b{re.escape(f)}{end}\b")
    return re.compile('|'.join(patterns), flags=re.IGNORECASE)

def sentences_verben_base(json_path, opensub_folder):
    with open(json_path, "r", encoding="utf-8") as f:
        word_list = json.load(f)

    unfilled = set()
    entry_map = {}
    pattern_map = {}

    for entry in word_list:
        if entry.get("例句", "") == "" and entry.get("原型"):
            word = entry["原型"]
            unfilled.add(word)
            entry_map[word] = entry
            pattern_map[word] = build_verb_patterns(entry)

    print(f"初始需要填充例句的动词数: {len(unfilled)}")

    part_files = sorted(
        [f for f in os.listdir(opensub_folder) if f.startswith("part_") and f.endswith(".txt")],
        key=lambda x: int(x.split("_")[1].split(".")[0])
    )
    random.shuffle(part_files)

    for fname in part_files:
        if not unfilled:
            print("所有动词都已找到例句，提前结束！")
            break

        fpath = os.path.join(opensub_folder, fname)
        with open(fpath, "r", encoding="utf-8", errors="ignore") as fin:
            for line in fin:
                sent = line.strip()
                if not sent:
                    continue
                for word in list(unfilled):
                    if pattern_map[word].search(sent):
                        entry_map[word]["例句"] = sent
                        unfilled.remove(word)
                        print(f"找到例句: {word} → {sent}")
                        break

    print(f"剩余未匹配到的动词数: {len(unfilled)}")

    out_json_path = json_path.replace(".json", "_with_examples.json")
    with open(out_json_path, "w", encoding="utf-8") as fout:
        json.dump(word_list, fout, ensure_ascii=False, indent=2)

    print(f"已完成，保存到 {out_json_path}")

# 示例调用
sentences_verben_base("public/data/verben_base.json", "public/OpenSubtitles")
# Out:
# 初始需要填充例句的动词数: 187
# 找到例句: sehen → Sie sehen blass aus.
# 找到例句: werden → Sie sahen morgens schon schlecht aus und es wurde schlimmer.
# 找到例句: gehen → Es geht mir gut.
# 找到例句: machen → Nein, ich habe heute früher Schluss gemacht.
# 找到例句: essen → Hast du gegessen?
# 找到例句: nehmen → Ich habe schon was genommen.
# 找到例句: denken → Ich habe mir schon gedacht, dass du früher kommst.
# 找到例句: schlafen → Ich will nur schlafen.
# 找到例句: bleiben → Du musst jetzt stark bleiben.
# 找到例句: schreiben → Warum schreiben Sie mir?
# 找到例句: kommen → Sonst kommen Sie zu mir.
# 找到例句: dauern → -Wenn es nicht zu lang dauert.
# 找到例句: sagen → Er sagte, es ginge ihm gut, aber er sah heute gar nicht gut aus.
# 找到例句: haben → Nach dem Zoff in der Bar hat mein Bruder alles bezahlt.
# 找到例句: mögen → Ich mag dich mehr
# 找到例句: sitzen → Was sitzt du zu Hause.
# 找到例句: brauchen → Nach einer Trennung braucht man Süßes.
# 找到例句: bringen → Er brachte sie mit einem Zug zum Schweigen.
# 找到例句: geben → Geben Sie sich nicht die Schuld.
# 找到例句: leben → Sie mischt sich in sein Leben ein?
# 找到例句: kaufen → Ich habe das für Sie gekauft.
# 找到例句: laufen → Wie lief das Meeting?
# 找到例句: passieren → Ist etwas passiert?
# 找到例句: ziehne an → Ich war nicht warm genug angezogen.
# 找到例句: besuchen → Du hast sie wirklich besucht und verlangt, dass sie Schluss macht?
# 找到例句: verletzen → Ich wollte nicht, dass er verletzt wird.
# 找到例句: fühlen → Ist dir egal, wie er sich fühlt?
# 找到例句: wissen → Ich habe das getan, weil ich weiß, dass er nicht aufgeben wird.
# 找到例句: treffen → Wenn er Entscheidungen trifft, solltest du ihn unterstützen.
# 找到例句: tun → Warum hast du das getan?
# 找到例句: vergessen → Sobald er heiratet und eigene Kinder hat, wird er das alles vergessen.
# 找到例句: verkaufen → Wir verkauften das Obst auf der Straße.
# 找到例句: lieben → Dabei haben wir erkannt, wie sehr wir einander lieben.
# 找到例句: stehen → Ich kann nicht dabei zusehen wie du und Menschen, die dir nah stehen, meinetwegen müde werden.
# 找到例句: verstehen → Aber mit der Zeit wirst du mich hoffentlich verstehen.
# 找到例句: trinken → Hast du gestern getrunken?
# 找到例句: nehmen mit → Als ich klein war, hast du mich in Galerien mitgenommen.
# 找到例句: frühstücken → Ich habe zu viel gefrühstückt.
# 找到例句: verlieren → Haben Sie den Appetit verloren?
# 找到例句: kennen → Und da Sie das Hotel am besten kennen, versetze ich Sie ins Management.
# 找到例句: behalten → Präsident Jung soll seine Aktien behalten.
# 找到例句: fragen → Ich möchte Sie etwas fragen.
# 找到例句: warten → Warten wir einfach ab.
# 找到例句: hören → Aber nachdem ich gehört habe, was sie sagte habe ich erkannt dass sie mit mir bloß in einen anderen Turm gesperrt worden wäre.
# 找到例句: glauben → Dass sie glaubt, sie sei daran schuld... dass alle um sie herum leiden.
# 找到例句: kommen her → Dass du gekommen bist, weil du mich verpasst hast.
# 找到例句: gewinnen → Was gewinnt?
# 找到例句: antworten → -Antworten Sie.
# 找到例句: bekommen → Bekamen Sie Geld von Taegyeong?
# 找到例句: reden → Wir reden später.
# 找到例句: kochen → Hast du das selbst gekocht?
# 找到例句: schmecken → Das schmeckt gut.
# 找到例句: beginnen → Es wird schwieriger, wenn der Prozess beginnt.
# 找到例句: verreisen → Lass uns verreisen, wenn der Prozess vorbei ist.
# 找到例句: passen → Meinst du, das passt zu uns?
# 找到例句: springen → Aber er sprang ins Feuer, um dich vor Taegyeong zu retten.
# 找到例句: üben → Üben wir es trotzdem.
# 找到例句: helfen → Ich bin nur sauer, dass ich Präsidentin Cha nicht helfen kann.
# 找到例句: empfehlen → Aber du hast es mir empfohlen.
# 找到例句: finden → Ich fand den Mut das zu sagen, weil das mit Präsidentin Cha nicht so enden soll.
# 找到例句: gefallen → Gefallen sie dir nicht?
# 找到例句: schenken → Geschenkt ist geschenkt.
# 找到例句: sprechen → Ich habe es zufällig gehört, als du mit Papa gesprochen hast.
# 找到例句: hassen → Du kannst mich dafür hassen.
# 找到例句: schneiden → Park machte den Schnitt und ich mache die Musik.
# 找到例句: kaufen ein → -Hast du eingekauft?
# 找到例句: fehlen → Später fehlt dir vielleicht die Zeit dafür.
# 找到例句: komemn wieder → Alles andere kommt wieder an seinen Platz.
# 找到例句: lesen → Ich bekomme drei Mahlzeiten, und ich kann Bücher lesen, für die ich nie Zeit hatte.
# 找到例句: holen → Können Sie mir meinen Schuh holen?
# 找到例句: schneien → Mann, es schneit sogar.
# 找到例句: fotografieren → Ich nehme ihn nicht ab, und ich werde mit meiner Kamera oft fotografieren.
# 找到例句: spielen → Spielt keine Rolle.
# 找到例句: lernen → Hat er nichts gelernt?
# 找到例句: heißen → -Es heißt "Hr.
# 找到例句: zahlen → Lass sie dafür zahlen.
# 找到例句: wandern → Er will wandern gehen, wenn er rauskommt.
# 找到例句: braten → -Oder gebratenen Kimchi-Reis?
# 找到例句: fahren → Fahren wir doch nach der Hochzeit!
# 找到例句: scheinen → Von diesen vielen Sternen scheint einer auf mich herab.
# 找到例句: teilen → Wir teilen eine große Nähe.
# 找到例句: schwimmen → Wir gehen schwimmen.
# 找到例句: posten → Manche Leute posten gerne negative Kommentare.
# 找到例句: bewegen → Immer im Kreis bewegen.
# 找到例句: suchen → Wir suchen Miyagi-Do.
# 找到例句: wehen → Seine Mutter lag 17 Stunden in den Wehen.
# 找到例句: begrüßen → Statt ihn auf dieser Welt zu begrüßen, habe ich hier den Alkohol einer dreitägigen Sauftour verarbeitet und versucht, den Mut aufzubringen, da rüberzugehen.
# 找到例句: unterrichten → Eines der besten Dinge war es, dich zu unterrichten,
# 找到例句: funktionieren → Wenn das nicht funktioniert, dann gar nichts.
# 找到例句: liegen → Er liegt vielleicht irgendwo in der Ecke und weint Veronica nach.
# 找到例句: gehen vorbei → Glaub mir, das geht vorbei.
# 找到例句: zählen → Die inneren Werte zählen.
# 找到例句: lachen → (LACHT)
# 找到例句: heiraten → Weil ich dich heiratete, und nur das zählt.
# 找到例句: backen → Ich backte Cupcakes für den Geburtstag ihrer Tochter, und du sagtest mir nie, dass du in sie verliebt warst?
# 找到例句: fliegen → Wie wäre es mit einer seiner Fliegen?
# 找到例句: lesen vor → Dann hat Brian Larkin den Brief laut im Flur vorgelesen.
# 找到例句: wohnen → - Wohnt hier Sheldon Cooper?
# 找到例句: rufen an → Sie haben mich angerufen, oder?
# 找到例句: tragen → Ich hörte, er trug keine Kontaktlinsen.
# 找到例句: beraten → Yoos Entlassung beraten wird.
# 找到例句: erreichen → Er konnte Sie nicht erreichen, also hat er mich geschickt.
# 找到例句: duschen → Geh duschen und zieh dich um.
# 找到例句: leiten → Meinst du, die leiten einfach so eine Untersuchung ein?
# 找到例句: planen → Weißt du, was die das ganze Jahr geplant haben?
# 找到例句: fahren weg → Ich lasse es aussehen, als seist du zur Behandlung weggefahren.
# 找到例句: kommen an → Ich bin noch nicht ganz unten angekommen.
# 找到例句: singen → Sogar Sang-beom suchte nach dir.
# 找到例句: fangen an → Ja, er hat ganz plötzlich angefangen.
# 找到例句: studieren → Sie studierten Elektronik an der Hanguk University.
# 找到例句: wiederholen → Soll ich es wiederholen?
# 找到例句: hängen → Was hängt da an deinen Ohren?
# 找到例句: bereiten vor → Ich bin schon vorbereitet.
# 找到例句: bestellen → Der Tisch da drüben hat zwei Tassen Kaffee bestellt.
# 找到例句: sagen ab → Sie haben Ihre Kurse abgesagt.
# 找到例句: lernen kennen → Hast du Emma besser kennengelernt?
# 找到例句: öffnen → An dem Tag, an dem der Schlüssel die Hand erreicht, öffnet sich das Tor, und der Palast zerfällt.
# 找到例句: kosten → Es hat mich viel Mut gekostet herzukommen.
# 找到例句: hoffen → Hoffen wir also, dass ich nicht festgenommen werde.
# 找到例句: buchen → José buchte einen Flug für ihn.
# 找到例句: kontrollieren → Ihr solltet die Firewall kontrollieren und sicherstellen...
# 找到例句: sehen aus → Es sieht aus, als tanzen sie, aber sie spielen ein AR-Videospiel mit Zugang über intelligente Kontaktlinsen.
# 找到例句: rauchen → Wir rollen uns was und rauchen zu Hause, inschallah.
# 找到例句: hören auf → Jungs, hört auf!
# 找到例句: reisen → -Sind Sie auf Reisen?
# 找到例句: unterschreiben → Das müssen Sie noch unterschreiben.
# 找到例句: kommen mit → -Sie kommt mit, ja.
# 找到例句: ruhen aus → Darum brauche ich konzentrierte, ausgeruhte Leute.
# 找到例句: joggen → Ich gehe joggen.
# 找到例句: mischen → Er mischt sich unter die Hipster.
# 找到例句: bleiben stehen → Meine Beine bleiben stehen Da ich fürchte, etwas zu bereuen
# 找到例句: korrigieren → ~ Übersetzt von apeg ~ ~ Timings von Steffi ~ Korrigiert von Shay-Zee ~
# 找到例句: streiten → Ich habe keine Zeit, mit dir zu streiten.
# 找到例句: stoppen → Ich hatte gehofft, nachdem sie gefeuert wurde, könnte Supergirl ihre Heldentaten darauf beschränken, entgleiste Züge zu stoppen und Kätzchen von Bäumen zu retten.
# 找到例句: servieren → Und ich denke an einen öffentlichen Ort, wo Essen an andere Menschen serviert wird, die es auch zu schätzen wissen.
# 找到例句: legen auf → - Du hast aufgelegt, bevor wir planen konnten.
# 找到例句: überprüfen → Gehen Sie, überprüfen Sie die Agenten.
# 找到例句: telefonieren → Ich muss telefonieren und einen neuen Zahnarzt für dich finden.
# 找到例句: putzen → Darum nannte ich sie so, und nun darf ich Fenster putzen, um irgendetwas über etwas zu lernen.
# 找到例句: reservieren → Sie haben nur eine Fahrkarte reserviert.
# 找到例句: angeln → Er angelt auch gerne.
# 找到例句: klettern → Klettern wir aus dem Fenster?
# 找到例句: übernachten → Das ist für bei euch übernachten.
# 找到例句: waschen → Wir müssen ihn nur waschen.
# 找到例句: feiern (feieren) → Wir feierten eine große Party in Connecticut, wo ich Assistenzarzt war.
# 找到例句: organisieren → Es gibt zu wenig Frauen im organisierten Verbrechen.
# 找到例句: biegen → Aber wir biegen das wieder hin.
# 找到例句: tanzen → Wir tanzen und lachen und vergessen die Welt, und auf einmal benutzen wir diese Sachen zusammen.
# 找到例句: gießen → Die Sportlerbräute nannten mich Dizzy Silva und gossen mir Säfte in den Rücken...
# 找到例句: parken → Parken am Bordstein.
# 找到例句: wachen auf → Zuvor bei Roswell, New Mexico... 50 Jahre nach dem Ereignis bin ich hier drin aufgewacht.
# 找到例句: reparieren → - Guerin hat sie repariert und jetzt erinnert sie mich nur noch an sein dummes Gesicht, dumme Stimme, dumme Hände...
# 找到例句: füttern → Shaun ist kein Hamster, mit dem man spielen kann, und bei dem es dann egal ist, wenn man ihn mal nicht füttert.
# 找到例句: besichtigen → Ich hab da was besichtigt.
# 找到例句: stehen auf → Die Leute stehen auf so was.
# 找到例句: gehen aus → * Der Motor geht aus. * Ich hab alles gemacht.
# 找到例句: zelten → Als ich klein war, fuhr ich mit meinem Papa oft zelten.
# 找到例句: schlafen ein → Mama, sie ist eingeschlafen.
# 找到例句: bekommen zurück → Mit dieser Sache, und meinem Haifischgeld, sollte ich ziemlich bald mein Auto zurückbekommen.
# 找到例句: geben zurück → Hast du den Parkausweis zurückgegeben?
# 找到例句: räumen auf → So, jetzt wird hier aufgeräumt!
# 找到例句: nehmen ab → Sie bekam Gläpol und Sauerstoff, Blut wurde schon abgenommen.
# 找到例句: ziehne aus → Der Mann wurde mit einer Eisenstange geschlagen, beraubt, ausgezogen.
# 找到例句: steigen aus → Steigt aus, kommt.
# 找到例句: nehmen zu → Sie hat so viel zugenommen.
# 找到例句: ziehen um → Du und deine Mom seid also oft umgezogen?
# 找到例句: pack ein → Ich habe auch ein paar deiner Klamotten eingepackt.
# 找到例句: würzen → Weil meine Gerichte perfekt gewürzt sind.
# 找到例句: frieren → Wenn es gefroren war, wäre es, als würde man eine Keule schwingen.
# 找到例句: haben frei → Sie haben frei, so lange wir in Japan sind.
# 找到例句: haben an → Wir haben an nur einem Tag das ganze Budget für ihn erarbeitet und es dann präsentiert.
# 找到例句: regnen → Und dann fing es an zu regnen.
# 找到例句: buchstabieren → "Tanz mit mir" buchstabieren.
# 找到例句: schlafen aus → - Ja, ich hab mal ausgeschlafen.
# 找到例句: sehen fern → Ich habe ferngesehen.
# 找到例句: finden statt → Weil es nicht stattgefunden hat.
# 找到例句: überqueren → Es gibt keinen einfachen Weg, den Highway zu überqueren.
# 找到例句: suchen weiter → Und wir suchen weiter.
# 找到例句: schälen → Du musst aufpassen beim Schälen, wir müssen sparen.
# 找到例句: faulenzen → Ich will einfach mal faulenzen.
# 找到例句: grillen → Ja, zum Grillen, aber es fällt auseinander, und Papa macht nichts.
# 找到例句: steigen um → Wir wissen, er stieg um 18:30 Uhr in Duralong Point aus und um 19:50 Uhr wieder ein.
# 找到例句: probieren an → - Du hast ihn gar nicht anprobiert.
# 找到例句: bestreuen → Kurz vor der Regatta bestreuen wir es einfach mit Bleichpulver.
# 找到例句: schreiben mit → Frau Laban, Sie schreiben mit!
# 找到例句: verrühren → Wir verrühren es.
# 找到例句: gehen entlang → Von all den Malen die wir diese Straße entlanggegangen sind, hab ich das hier schon mal gemacht?
# 所有动词都已找到例句，提前结束！
# 剩余未匹配到的动词数: 0
# 已完成，保存到 public/data/verben_base_with_examples.json

# %%
# add the sentence for verben phrasen manually
